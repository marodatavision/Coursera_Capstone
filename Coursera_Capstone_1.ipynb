# %% [markdown]
# # Coursera Capstone Project
# ### This Notebook is mainly used for the last course in the IBM Data Science Professional specialization
#
# *Python 3.7 Jupyter Notebook for Data Science*
#
# __Created By Maximilian Rosen__

# %% [markdown]
# At First let's import some essential packages and tool for Data Science with Python

# %%
# All imports for this notebook
import pandas as pd
import numpy as np

# %% [markdown]
# Here comes the first difficult task: __print a string__

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
